# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\swapn\Downloads\student_performance_large_dataset.csv")
df.head()
# Out:
#   Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0     S00001   18  Female                    48              Kinesthetic
# 1     S00002   29  Female                    30          Reading/Writing
# 2     S00003   20  Female                    47              Kinesthetic
# 3     S00004   23  Female                    13                 Auditory
# 4     S00005   19  Female                    24                 Auditory
#
#    Online_Courses_Completed Participation_in_Discussions  \
# 0                        14                          Yes
# 1                        20                           No
# 2                        11                           No
# 3                         0                          Yes
# 4                        19                          Yes
#
#    Assignment_Completion_Rate (%)  Exam_Score (%)  Attendance_Rate (%)  \
# 0                             100              69                   66
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Study_Hours_per_Week',
#        'Preferred_Learning_Style', 'Online_Courses_Completed',
#        'Participation_in_Discussions', 'Assignment_Completion_Rate (%)',
#        'Exam_Score (%)', 'Attendance_Rate (%)', 'Use_of_Educational_Tech',
#        'Self_Reported_Stress_Level', 'Time_Spent_on_Social_Media (hours/week)',
#        'Sleep_Hours_per_Night', 'Final_Grade'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Age'],df['Study_Hours_per_Week'])
plt.xlabel("Age")
plt.ylabel("Study_Hours_per_Week")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(15,8))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
columns_plot=['Assignment_Completion_Rate (%)',
       'Exam_Score (%)', 'Attendance_Rate (%)', 'Use_of_Educational_Tech',
       'Self_Reported_Stress_Level']
for i in columns_plot:
    bar_plot(i)
# Out:
# Assignment_Completion_Rate (%):
#  Assignment_Completion_Rate (%)
# 76     229
# 93     225
# 81     220
# 72     214
# 73     212
# 68     209
# 62     208
# 96     208
# 88     207
# 67     206
# 89     205
# 82     205
# 52     205
# 66     205
# 53     204
# 60     203
# 65     203
# 55     202
# 50     201
# 79     200
# 78     200
# 77     199
# 87     199
# 61     197
# 98     197
# 75     197
# 56     197
# 58     196
# 86     196
# 80     195
# 71     194
# 92     193
# 54     193
# 91     193
# 90     191
# 95     191
# 51     189
# 99     189
# 64     188
# 59     187
# 63     186
# 100    184
# 85     184
# 94     183
# 84     181
# 74     181
# 57     180
# 97     172
# 70     169
# 69     165
# 83     163
# Name: count, dtype: int64
# Exam_Score (%):
#  Exam_Score (%)
# 55    187
# 94    185
# 99    184
# 64    184
# 71    183
#      ...
# 95    147
# 53    147
# 60    146
# 96    145
# 59    134
# Name: count, Length: 61, dtype: int64
# Attendance_Rate (%):
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Study_Hours_per_Week',
#        'Preferred_Learning_Style', 'Online_Courses_Completed',
#        'Participation_in_Discussions', 'Assignment_Completion_Rate (%)',
#        'Exam_Score (%)', 'Attendance_Rate (%)', 'Use_of_Educational_Tech',
#        'Self_Reported_Stress_Level', 'Time_Spent_on_Social_Media (hours/week)',
#        'Sleep_Hours_per_Night', 'Final_Grade'],
#       dtype='object')

# %%
plt.hist(df['Attendance_Rate (%)'])
plt.show()

# %%
plt.hist(df['Exam_Score (%)'])
plt.show()

# %%
plt.hist(df['Time_Spent_on_Social_Media (hours/week)'])
plt.show()

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
sns.boxplot(y='Time_Spent_on_Social_Media (hours/week)',data=df)
# Out:
# <Axes: ylabel='Time_Spent_on_Social_Media (hours/week)'>

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                                 0
# Age                                        0
# Gender                                     0
# Study_Hours_per_Week                       0
# Preferred_Learning_Style                   0
# Online_Courses_Completed                   0
# Participation_in_Discussions               0
# Assignment_Completion_Rate (%)             0
# Exam_Score (%)                             0
# Attendance_Rate (%)                        0
# Use_of_Educational_Tech                    0
# Self_Reported_Stress_Level                 0
# Time_Spent_on_Social_Media (hours/week)    0
# Sleep_Hours_per_Night                      0
# Final_Grade                                0
# dtype: int64

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
df['Assignment_Completion_Rate (%)'] = pd.to_numeric(df['Assignment_Completion_Rate (%)'], errors='coerce')

# %%
df['Assignment_Completion_Rate (%)'].fillna(df['Assignment_Completion_Rate (%)'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Student_ID                                 0
# Age                                        0
# Gender                                     0
# Study_Hours_per_Week                       0
# Preferred_Learning_Style                   0
# Online_Courses_Completed                   0
# Participation_in_Discussions               0
# Assignment_Completion_Rate (%)             0
# Exam_Score (%)                             0
# Attendance_Rate (%)                        0
# Use_of_Educational_Tech                    0
# Self_Reported_Stress_Level                 0
# Time_Spent_on_Social_Media (hours/week)    0
# Sleep_Hours_per_Night                      0
# Final_Grade                                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Study_Hours_per_Week',
#        'Preferred_Learning_Style', 'Online_Courses_Completed',
#        'Participation_in_Discussions', 'Assignment_Completion_Rate (%)',
#        'Exam_Score (%)', 'Attendance_Rate (%)', 'Use_of_Educational_Tech',
#        'Self_Reported_Stress_Level', 'Time_Spent_on_Social_Media (hours/week)',
#        'Sleep_Hours_per_Night', 'Final_Grade'],
#       dtype='object')

# %%
df.drop(labels=['Student_ID','Gender','Preferred_Learning_Style','Participation_in_Discussions','Use_of_Educational_Tech',
       'Self_Reported_Stress_Level','Final_Grade'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                                        0
# Study_Hours_per_Week                       0
# Online_Courses_Completed                   0
# Assignment_Completion_Rate (%)             0
# Exam_Score (%)                             0
# Attendance_Rate (%)                        0
# Time_Spent_on_Social_Media (hours/week)    0
# Sleep_Hours_per_Night                      0
# dtype: int64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
